# %% [markdown]
# # Graph Representation of Recent Grad Student Data
# -------

# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
recent_grads = recent_grads.dropna()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
cleaned_data_count=recent_grads.shape
print(cleaned_data_count)
# Out:
# (172, 21)

# %% [markdown]
# # Scatter Plots
# ----
# * Do students in more popular majors make more money?
# * Do students that majored in subjects that were majority female make more money?
# * Is there any link between the number of full-time employees and median salary?

# %%
recent_grads.plot(x='Sample_size' , y='Median', kind = 'scatter')

# %%
recent_grads.plot(x='Sample_size' , y='Unemployment_rate', kind = 'scatter')

# %%
recent_grads.plot(x='Full_time' , y='Median', kind = 'scatter')

# %%
recent_grads.plot(x='ShareWomen' , y='Unemployment_rate', kind = 'scatter')

# %%
recent_grads.plot(x='Men' , y='Median', kind = 'scatter')

# %%
recent_grads.plot(x='Women' , y='Median', kind = 'scatter')

# %%
recent_grads['Sample_size'].hist(bins = 25, range = (0,3000))

# %%
cols = ['Sample_size', 'Median',
'Employed',
'Full_time',
'ShareWomen',
'Unemployment_rate',
'Men',
'Women']

fig = plt.figure(figsize = (5,12))

for i in range(1,4):
    ax = fig.add_subplot(4,1,i)
    ax = recent_grads[cols[i]].plot(kind = 'hist', rot = 20)
    
plt.show()

# %%
cols = ['Sample_size', 'Median',
'Employed',
'Full_time',
'ShareWomen',
'Unemployment_rate',
'Men',
'Women']

fig = plt.figure(figsize = (5,12))

for i in range(4,8):
    ax = fig.add_subplot(4,1,i-3)
    ax = recent_grads[cols[i]].plot(kind = 'hist', rot = 20)
    
plt.show()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f544e262470>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f544de39eb8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Total', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f544dc690b8>,
# ...
#       dtype=object)

# %%
first_ten = recent_grads.head(10)
last_ten = recent_grads.tail(10)

# %%
first_ten.plot.bar(x="Major", y= "ShareWomen", legend = False)
last_ten.plot.bar(x="Major", y= "ShareWomen", legend= False)

# %%
first_ten.plot.bar(x="Major", y= "Unemployment_rate", legend = False)
last_ten.plot.bar(x="Major", y= "Unemployment_rate", legend= False)

# %%
barWidth = 0.25
 
# set height of bar

 
# Set position of bar on X axis

 
# Make the plot
plt.bar(5, recent_grads['Major'], color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(5, recent_grads['Men'], color='#557f2d', width=barWidth, edgecolor='white', label='var2')
plt.bar(5, recent_grads['Unemployment_rate'], color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-60-73237c71ab55> in <module>()
#       8
#       9 # Make the plot
# ---> 10 plt.bar(5, recent_grads['Major'], color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
#      11 plt.bar(5, recent_grads['Men'], color='#557f2d', width=barWidth, edgecolor='white', label='var2')
#      12 plt.bar(5, recent_grads['Unemployment_rate'], color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2641     try:
#    2642         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2643                      **kwargs)
#    2644     finally:
#    2645         ax.hold(washold)
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...
